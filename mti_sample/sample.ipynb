# %%
import mesh
import viz
import nma

# %%
mesh_3m = mesh.mesh_from_models('1D_3m')
viz.draw_mesh(mesh_3m)

# %%
nma_3m = nma.NMA(mesh_3m, save_flag=True, model_dir='mesh_3m')
viz.draw_whist(nma_3m)

# %%
mesh_tr = mesh.mesh_from_models('2D_tr')
viz.draw_mesh(mesh_tr)

# %%
nma_tr = nma.NMA(mesh_tr, save_flag=True, model_dir='mesh_tr')
viz.draw_whist(nma_tr)

# %%
mesh_poly5 = mesh.polygon_mesh(r=5, N=5, fully_connect=False)
viz.draw_mesh(mesh_poly5)

# %%
nma_poly5 = nma.NMA(mesh_poly5, save_flag=True, model_dir='mesh_poly5')
viz.draw_whist(nma_poly5)

# %%
mesh_poly5x = mesh.polygon_mesh(r=5, N=5, fully_connect=True)
viz.draw_mesh(mesh_poly5x)

# %%
nma_poly5x = NMA(mesh_poly5x, save_flag=True, model_dir='mesh_poly5x')
viz.draw_whist(nma_poly5x)
