# %%
from steps import mesh, nma, viz

# %%
mesh_3m = mesh.mesh_from_models('1D_3masses')
viz.draw_mesh(mesh_3m)

# %%
nma_3m = nma.NMA(mesh_3m)
viz.draw_whist(nma_3m)

# %%
mesh_tr = mesh.mesh_from_models('2D_triangle')
viz.draw_mesh(mesh_tr)

# %%
nma_tr = nma.NMA(mesh_tr)
viz.draw_whist(nma_tr)

# %%
mesh_poly5 = mesh.polygon_mesh(r=5, N=5, fully_connect=False)
viz.draw_mesh(mesh_poly5)

# %%
nma_poly5 = nma.NMA(mesh_poly5)
viz.draw_whist(nma_poly5)

# %%
mesh_poly5x = mesh.polygon_mesh(r=5, N=5, fully_connect=True)
viz.draw_mesh(mesh_poly5x)

# %%
nma_poly5x = nma.NMA(mesh_poly5x)
viz.draw_whist(nma_poly5x)

# %%
viz.draw_whist_multi([nma_poly5,nma_poly5x])

# %%
mesh_vol1 = mesh.volume_trimesh(r=5, ss=1, fully_connect=False)
viz.draw_mesh(mesh_vol1)

# %%
nma_vol1 = nma.NMA(mesh_vol1)
viz.draw_whist(nma_vol1)

# %%
mesh_vol3 = mesh.volume_trimesh(r=5, ss=3, fully_connect=False)
viz.draw_mesh(mesh_vol3)

# %%
nma_vol3 = nma.NMA(mesh_vol3,)
viz.draw_whist(nma_vol3)

# %%
viz.draw_whist_multi([nma_vol1,nma_vol3])
